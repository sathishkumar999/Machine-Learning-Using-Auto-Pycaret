# %%
import pandas as pd
import numpy as np

# %%
# Importing the data
data=pd.read_excel(r"D:\House-Price-Prediction\house_price.xlsx")

# %%
from pycaret.utils import version
version()
# Out:
# 1.0.0

# %%
dataset=pd.DataFrame(data)

# %%
# Number of columns in data set
dataset.shape
# Out:
# (1000, 8)

# %%
# Reading first five records in data set
dataset.head()
# Out:
#    Unnamed: 0      Location  BHK  Furnishing  Sq.ft  Old(years)  Floor  Price
# 0          37  Bommanahalli    3           1   3000           1      3  28000
# 1          43  Bommanahalli    3           1   1650          10      0  18000
# 2          12    Whitefield    2           0   1000           5      3  16400
# 3           8    Whitefield    3           0   1600           1      9  27000
# 4           9    Whitefield    2           1   1200           5      1  20000

# %%
# Displaying the column names
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Location', 'BHK', 'Furnishing', 'Sq.ft', 'Old(years)',
#        'Floor', 'Price'],
#       dtype='object')

# %%
# Removing the column
data=data.drop('Unnamed: 0',axis=1)
data.head()
# Out:
#        Location  BHK  Furnishing  Sq.ft  Old(years)  Floor  Price
# 0  Bommanahalli    3           1   3000           1      3  28000
# 1  Bommanahalli    3           1   1650          10      0  18000
# 2    Whitefield    2           0   1000           5      3  16400
# 3    Whitefield    3           0   1600           1      9  27000
# 4    Whitefield    2           1   1200           5      1  20000

# %%
# Renaming the columns
data=data.rename(columns={'Sq.ft':'Square_feet','Old(years)':'Old_years'})
data.head()
# Out:
#        Location  BHK  Furnishing  Square_feet  Old_years  Floor  Price
# 0  Bommanahalli    3           1         3000          1      3  28000
# 1  Bommanahalli    3           1         1650         10      0  18000
# 2    Whitefield    2           0         1000          5      3  16400
# 3    Whitefield    3           0         1600          1      9  27000
# 4    Whitefield    2           1         1200          5      1  20000

# %%
# Finding the number of missing values
data.isnull().sum()
# Out:
# Location       0
# BHK            0
# Furnishing     0
# Square_feet    0
# Old_years      0
# Floor          0
# Price          0
# dtype: int64

# %%
# Displaying the type of the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     1000 non-null   object
#  1   BHK          1000 non-null   int64
#  2   Furnishing   1000 non-null   int64
#  3   Square_feet  1000 non-null   int64
#  4   Old_years    1000 non-null   int64
#  5   Floor        1000 non-null   int64
#  6   Price        1000 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 54.8+ KB

# %%
# Displaying the summary of data
data.describe()
# Out:
#                BHK   Furnishing  Square_feet    Old_years        Floor  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.436000     0.348000  1448.613000     4.029000     3.465000
# std       0.496135     0.476574   491.272535     3.048845     3.245197
# min       2.000000     0.000000   767.000000     1.000000     0.000000
# 25%       2.000000     0.000000  1089.000000     1.000000     1.000000
# 50%       2.000000     0.000000  1300.000000     5.000000     3.000000
# 75%       3.000000     1.000000  1650.000000     5.000000     3.000000
# max       3.000000     1.000000  3155.000000    10.000000    13.000000
#
#               Price
# count   1000.000000
# mean   22829.900000
# std     7706.410627
# min    11000.000000
# 25%    16500.000000
# 50%    21000.000000
# 75%    26000.000000
# max    45000.000000

# %% [raw]
# # Importing module and initializing setup(Here it asks the percentage of data for training, suppose you want to 70% of data for training,You shoud type as .7 and it will take .3 data for testing by default)
# # It can even handle categorical columns,there is no need to encoding it. And also Handles the missing features by default.

# %%
# Importing module and initializing setup
from pycaret.regression import *
reg1 = setup(data = data, target = 'Price')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_9a45e676_8635_11ea_b286_60f26276bd11" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row0_col1" class="data row0 col1" >856</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row3_col1" class="data row3 col1" >(1000, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row5_col1" class="data row5 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row6_col1" class="data row6 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row10_col1" class="data row10 col1" >(1000, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row11_col1" class="data row11 col1" >(699, 19)</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row12_col1" class="data row12 col1" >(301, 19)</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_9a45e676_8635_11ea_b286_60f26276bd11level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_9a45e676_8635_11ea_b286_60f26276bd11row18_col1" class="data row18 col1" >None</td>
#             </t

# %%
# comparing all models
compare_models()
# Out:
# <style  type="text/css" >
#     #T_aa49a130_8635_11ea_96d8_60f26276bd11 th {
#           text-align: left;
#     }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row1_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row2_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row4_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row8_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col1 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col2 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col3 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col4 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col5 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row9_col6 {
#             : ;
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row10_col0 {
#             text-align:  left;
#         }    #T_aa49a130_8635_11ea_96d8_60f26276bd11row10_col1 {
#             :

# %% [raw]
# # while comparing all the regression models, the Decision tree and Extra tree has given Higher score for 'R2' and low score for 'MAE,MSE,RMSE'.
# # But here I'm using the random forest model to improving the accuracy by tuning, Just to see how does it work.

# %%
# creating a model(by default it has 10 folds and round as 4)
#rf= create_model('rf', fold = 5, round = 2)
rf= create_model('rf')
# Out:
#          MAE       MSE     RMSE   R2   RMSLE    MAPE
# 0     0.0000    0.0000   0.0000  1.0  0.0000  0.0000
# 1     1.7143   68.5714   8.2808  1.0  0.0004  0.0001
# 2     0.0000    0.0000   0.0000  1.0  0.0000  0.0000
# 3     3.2857  377.8571  19.4385  1.0  0.0010  0.0002
# 4     0.0000    0.0000   0.0000  1.0  0.0000  0.0000
# 5     0.0000    0.0000   0.0000  1.0  0.0000  0.0000
# 6     0.2857    2.8571   1.6903  1.0  0.0001  0.0000
# 7     0.0000    0.0000   0.0000  1.0  0.0000  0.0000
# 8     0.1429    1.4286   1.1952  1.0  0.0001  0.0000
# 9     0.1449    1.4493   1.2039  1.0  0.0001  0.0000
# Mean  0.5573   45.2164   3.1809  1.0  0.0002  0.0000
# SD    1.0369  112.7143   5.9244  0.0  0.0003  0.0001

# %%
# parameters Inside the model
print(rf)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=856, verbose=0, warm_start=False)

# %%
# Bagging ensemble method
#tuned_bagged_dt = tune_model('dt', ensemble = True, method = 'Bagging', n_iter = 100)

# %%
# Boosting ensemble method
#tuned_boosted_dt = tune_model('dt', ensemble = True, method = 'Boosting', n_iter = 100)

# %%
# tuning the model to optimizing the parameters(By default it has no.of iterations are 10 and optimizes the R2)
#tuned_rf = tune_model('rf', n_iter = 50, optimize = 'mae')
tuned_rf = tune_model('rf')
# Out:
#           MAE        MSE     RMSE      R2   RMSLE    MAPE
# 0      2.9946   113.5965  10.6582  1.0000  0.0005  0.0002
# 1     16.6085  1285.0793  35.8480  1.0000  0.0018  0.0008
# 2      4.3609   147.5246  12.1460  1.0000  0.0006  0.0002
# 3     17.3444  3688.4110  60.7323  0.9999  0.0030  0.0008
# 4      6.9400   246.5528  15.7020  1.0000  0.0008  0.0003
# 5      7.8350   466.8050  21.6057  1.0000  0.0010  0.0003
# 6      3.2037   171.6453  13.1013  1.0000  0.0007  0.0002
# 7      8.1387   276.4590  16.6271  1.0000  0.0007  0.0004
# 8      3.4987   139.9770  11.8312  1.0000  0.0005  0.0001
# 9      1.2840    12.1906   3.4915  1.0000  0.0002  0.0001
# Mean   7.2208   654.8241  20.1743  1.0000  0.0010  0.0003
# SD     5.3216  1068.0288  15.7423  0.0000  0.0008  0.0003

# %%
# parameters after tuning
print(tuned_rf)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=80, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=2,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=130, n_jobs=None, oob_score=False,
#                       random_state=856, verbose=0, warm_start=False)

# %%
# plotting the model for evaluating the train and test scores
plot_model(tuned_rf)

# %%
# plotting the regression line for the model
plot_model(tuned_rf, plot = 'error')

# %%
#plot_model(tuned_rf, plot='feature')

# %%
# plotting all the evaluated metrics for regression
evaluate_model(tuned_rf);
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(tuned_rf);
# Out:
#                      Model     MAE       MSE     RMSE   R2   RMSLE    MAPE
# 0  Random Forest Regressor  2.7544  308.7782  17.5721  1.0  0.0009  0.0001

# %%
# finalizing the model for deployment
final_model = finalize_model(tuned_rf)

# %%
# saving the final model
save_model(final_model,'Final Model for Hosue price')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
# loading the model for prediction on new data
saved_final_model = load_model('Final Model for Hosue price')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
# Extracting 100 records for prediction
#data_unseen=data_unseen.drop('Price',axis=1)
data_unseen=data.iloc[0:100,:]

# %%
# Predicting the House price on new data
new_prediction = predict_model(saved_final_model, data=data_unseen)

# %%
# comparing the house prices (Actual price: Price, Predicted price: Label)
# 100% accuracy has achieved on new data
new_prediction.head(100)
# Out:
#         Location  BHK  Furnishing  Square_feet  Old_years  Floor  Price  \
# 0   Bommanahalli    3           1         3000          1      3  28000
# 1   Bommanahalli    3           1         1650         10      0  18000
# 2     Whitefield    2           0         1000          5      3  16400
# 3     Whitefield    3           0         1600          1      9  27000
# 4     Whitefield    2           1         1200          5      1  20000
# ..           ...  ...         ...          ...        ...    ...    ...
# 95  Bommanahalli    2           0         1135         10      2  16000
# 96    Whitefield    3           0         2117          1      0  33000
# 97  Bommanahalli    2           0          950          5      1  14000
# 98  Bommanahalli    2           1         1300          5      3  20000
# 99    Whitefield    2           1         1600          5      4  24000
#
#       Label
# 0   28000.0
# 1   18000.0
# 2   16400.0
# 3   27000.0
# 4   20000.0
# ..      ...
# 95  16000.0
# 96  33000.0
# 97  14000.0
# 98  20000.0
# 99  24000.0
#
# [100 rows x 8 columns]
